# %%
# !pip install --upgrade google-cloud-bigquery-storage

# %%
from google.colab import auth
auth.authenticate_user()
from google.cloud import storage, bigquery

project_id = 'wpac-449904'
# Create a storage client
client = bigquery.Client(project=project_id)
# Out:
# WARNING: google.colab.auth.authenticate_user() is not supported in Colab Enterprise.

# %%
query = """
SELECT * FROM `wpac-449904.wpac_data.careers`
"""
careers = client.query(query).to_dataframe()

# Display first few rows
careers.head()
# Out:
#               data_careerId                 createdAt          education  \
# 0  63e542ec3f747a7a197b9bd9 2023-02-10 00:01:00+00:00  Bachelor's degree
# 1  63e543523f747a7a197b9c48 2023-02-10 00:02:42+00:00  Bachelor's degree
# 2  63e5434b3f747a7a197b9c41 2023-02-10 00:02:35+00:00  Bachelor's degree
# 3  63e543453f747a7a197b9c3a 2023-02-10 00:02:29+00:00  Bachelor's degree
# 4  63e5433e3f747a7a197b9c33 2023-02-10 00:02:22+00:00  Bachelor's degree
#
#                                           jobZone    onetCode  \
# 0  Job Zone Four: Considerable Preparation Needed  13-1071.00
# 1  Job Zone Four: Considerable Preparation Needed  15-1253.00
# 2  Job Zone Four: Considerable Preparation Needed  15-1252.00
# 3  Job Zone Four: Considerable Preparation Needed  15-1244.00
# 4  Job Zone Four: Considerable Preparation Needed  27-1024.00
#
#                                          onetTitle  \
# 0                      Human Resources Specialists
# 1  Software Quality Assurance Analysts and Testers
# 2                              Software Developers
# 3      Network and Computer Systems Administrators
# 4                                Graphic Designers
#
#                                              title  \
# 0                      Human Resources Specialists
# 1  Software Quality Assurance Analysts and Testers
# 2                              Software Developers
# 3      Network and Computer Systems Administrators
# 4                                Graphic Designers
#
#                                   titleSingular                 updatedAt
# 0                    Human Resources Specialist 2024-01-25 04:39:23+00:00
# 1  Software Quality Assurance Analyst or Tester 2024-01-25 04:37:49+00:00
# 2                            Software Developer 2024-01-25 04:37:54+00:00
# 3    Network and Computer Systems Administrator 2024-01-25 04:38:01+00:00
# 4                              Graphic Designer 2024-01-25 04:38:07+00:00

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
print(careers.nunique())
careers.info()
# Out:
# data_careerId    40
# createdAt        40
# education         6
# jobZone           3
# onetCode         40
# onetTitle        40
# title            40
# titleSingular    37
# updatedAt        40
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   data_careerId  40 non-null     object
#  1   createdAt      40 non-null     datetime64[us, UTC]
#  2   education      40 non-null     object
#  3   jobZone        40 non-null     object
#  4   onetCode       40 non-null     object
#  5   onetTitle      40 non-null     object
#  6   title          40 non-null     object
#  7   titleSingular  40 non-null     object
#  8   updatedAt      40 non-null     datetime64[us, UTC]
# dtypes: datetime64[us, UTC](2), object(7)
# memory usage: 2.9+ KB

# %%
careers.drop(columns=['createdAt', 'onetCode', 'title', 'titleSingular', 'updatedAt'], axis=1, inplace=True)
careers.head()
# Out:
#               data_careerId          education  \
# 0  63e542ec3f747a7a197b9bd9  Bachelor's degree
# 1  63e543523f747a7a197b9c48  Bachelor's degree
# 2  63e5434b3f747a7a197b9c41  Bachelor's degree
# 3  63e543453f747a7a197b9c3a  Bachelor's degree
# 4  63e5433e3f747a7a197b9c33  Bachelor's degree
#
#                                           jobZone  \
# 0  Job Zone Four: Considerable Preparation Needed
# 1  Job Zone Four: Considerable Preparation Needed
# 2  Job Zone Four: Considerable Preparation Needed
# 3  Job Zone Four: Considerable Preparation Needed
# 4  Job Zone Four: Considerable Preparation Needed
#
#                                          onetTitle
# 0                      Human Resources Specialists
# 1  Software Quality Assurance Analysts and Testers
# 2                              Software Developers
# 3      Network and Computer Systems Administrators
# 4                                Graphic Designers

# %%
for col in careers.columns:
  print(careers[col].value_counts(dropna=False))
  print('-'*100)
# Out:
# data_careerId
# 63e542ec3f747a7a197b9bd9    1
# 63e543523f747a7a197b9c48    1
# 63e543153f747a7a197b9c06    1
# 63e542ca3f747a7a197b9bb3    1
# 63e542ad3f747a7a197b9b97    1
# 63e5427c3f747a7a197b9b66    1
# 63e542673f747a7a197b9b51    1
# 63e542623f747a7a197b9b4a    1
# 63e5425b3f747a7a197b9b43    1
# 667a3e7b660b43e385d67b63    1
# 63e543373f747a7a197b9c2c    1
# 63e542d83f747a7a197b9bc1    1
# 63e543313f747a7a197b9c25    1
# 63e542d13f747a7a197b9bba    1
# 63e542c33f747a7a197b9bac    1
# 63e542973f747a7a197b9b82    1
# 63e5428a3f747a7a197b9b74    1
# 64c97d56d590f3086430cabe    1
# 6717fbfd9d87c463f63b7510    1
# 667a3e61660b43e385d67a14    1
# 64c97bd1d590f3086430c90f    1
# 674e049aa15fc5146f9b4914    1
# 63e542df3f747a7a197b9bca    1
# 63e5434b3f747a7a197b9c41    1
# 63e543453f747a7a197b9c3a    1
# 63e5433e3f747a7a197b9c33    1
# 63e542fa3f747a7a197b9be7    1
# 63e5430f3f747a7a197b9bff    1
# 63e543013f747a7a197b9bf0    1
# 63e542f33f747a7a197b9be0    1
# 64c97c4fd590f3086430c974    1
# 64c97d0bd590f3086430ca6f    1
# 64c97c9ed590f3086430c9cd    1
# 63e543593f747a7a197b9c4f    1
# 63e5431c3f747a7a197b9c0f    1
# 63e543083f747a7a197b9bf8    1
# 63e542bc3f747a7a197b9ba5    1
# 63e542b53f747a7a197b9b9e    1
# 63e5429f3f747a7a197b9b89    1
# 63e543233f747a7a197b9c17    1
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# education
# High school diploma or equivalent    17
# Postsecondary certificate            11
# Bachelor's degree                     7
# Associate's degree                    2
# Some college, no degree               2
# No formal educational credential      1
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# jobZone
# Job Zone Three: Medium Preparation Needed         22
# Job Zone Four: Considerable Preparation Needed    10
# Job Zone Two: Some Preparation Needed              8
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# onetTitle
# Human Resources Specialists                                                                     1
# Software Quality Assurance Analysts and Testers                                                 1
# Automotive Service Technicians and Mechanics                                                    1
# Telecommunications Equipment Installers and Repairers, Except Line Installers                   1
# Heating, Air Conditioning, and Refrigeration Mechanics and Installers                           1
# Phlebotomists                                                                                   1
# Medical Records Specialists                                                                     1
# Medical Assistants                                                                              1
# Licensed Practical and Licensed Vocational Nurses                                               1
# Surgical Technologists                                                                          1
# Computer User Support Specialists                                                               1
# Bookkeeping, Accounting, and Auditing Clerks                                                    1
# Production, Planning, and Expediting Clerks                                                     1
# Welders, Cutters, Solderers, and Brazers                                                        1
# Solar Photovoltaic Installers                                                                   1
# Electrical Power-Line Installers and Repairers                                                  1
# Carpenters                                                                                      1
# Operating Engineers and Other Construction Equipment Operators                                  1
# Industrial Truck and Tractor Operators                                                          1
# Paramedics                                                                                      1
# Dental Assistants                                                                               1
# Pharmacy Technicians                                                                            1
# Claims Adjusters, Examiners, and Investigators                                                  1
# Software Developers                                                                             1
# Network and Computer Systems Administrators                                                     1
# Graphic Designers                                                                               1
# Loan Officers                                                                                   1
# Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products    1
# Property, Real Estate, and Community Association Managers                                       1
# Insurance Sales Agents                                                                          1
# Industrial Engineering Technologists and Technicians                                            1
# Mobile Heavy Equipment Mechanics, Except Engines                                                1
# Electrical and Electronic Engineering Technologists and Technicians                             1
# Web Developers                                                                                  1
# Bus and Truck Mechanics and Diesel Engine Specialists                                           1
# Real Estate Sales Agents                                                                        1
# Police and Sheriff's Patrol Officers                                                            1
# Plumbers, Pipefitters, and Steamfitters                                                         1
# Electricians                                                                                    1
# Heavy and Tractor-Trailer Truck Drivers                                                         1
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %%
education_map = {
    'No formal educational credential':'0',
    'High school diploma or equivalent':'1',
    'Some college, no degree':'2',
    'Postsecondary certificate':'3',
    "Associate's degree":'4',
    "Bachelor's degree":'5'
}
careers['education'] = careers['education'].replace(education_map)
careers['education'] = careers['education'].astype('category')
careers['education'].cat.reorder_categories(['0','1','2','3','4','5'], ordered=True)

# Verify changes
print(careers['education'].value_counts(dropna=False))
# Out:
# education
# 1    17
# 3    11
# 5     7
# 2     2
# 4     2
# 0     1
# Name: count, dtype: int64

# %%
job_map= {
    'Job Zone Three: Medium Preparation Needed':'3',
    'Job Zone Four: Considerable Preparation Needed':'4',
    'Job Zone Two: Some Preparation Needed':'2'
}

careers['jobZone'] = careers['jobZone'].replace(job_map)
careers['jobZone'] = careers['jobZone'].astype('category')

print(careers['jobZone'].value_counts(dropna=False))
# Out:
# jobZone
# 3    22
# 4    10
# 2     8
# Name: count, dtype: int64

# %%
careers.head(40)
# Out:
#                data_careerId education jobZone  \
# 0   63e542ec3f747a7a197b9bd9         5       4
# 1   63e543523f747a7a197b9c48         5       4
# 2   63e5434b3f747a7a197b9c41         5       4
# 3   63e543453f747a7a197b9c3a         5       4
# 4   63e5433e3f747a7a197b9c33         5       4
# 5   63e542fa3f747a7a197b9be7         5       4
# 6   63e5430f3f747a7a197b9bff         1       4
# 7   63e543013f747a7a197b9bf0         1       4
# 8   63e542f33f747a7a197b9be0         1       4
# 9   63e542df3f747a7a197b9bca         1       4
# 10  64c97c4fd590f3086430c974         4       3
# 11  64c97c9ed590f3086430c9cd         4       3
# 12  63e543593f747a7a197b9c4f         5       3
# 13  63e5431c3f747a7a197b9c0f         1       3
# 14  63e543083f747a7a197b9bf8         1       3
# 15  63e542bc3f747a7a197b9ba5         1       3
# 16  63e542b53f747a7a197b9b9e         1       3
# 17  63e5429f3f747a7a197b9b89         1       3
# 18  64c97d0bd590f3086430ca6f         1       3
# 19  674e049aa15fc5146f9b4914         1       3
# 20  64c97bd1d590f3086430c90f         3       3
# 21  667a3e61660b43e385d67a14         3       3
# 22  63e543153f747a7a197b9c06         3       3
# 23  63e542ca3f747a7a197b9bb3         3       3
# 24  63e542ad3f747a7a197b9b97         3       3
# 25  63e5427c3f747a7a197b9b66         3       3
# 26  63e542673f747a7a197b9b51         3       3
# 27  63e542623f747a7a197b9b4a         3       3
# 28  63e5425b3f747a7a197b9b43         3       3
# 29  667a3e7b660b43e385d67b63         3       3
# 30  63e543373f747a7a197b9c2c         2       3
# 31  63e542d83f747a7a197b9bc1         2       3
# 32  63e543313f747a7a197b9c25         1       2
# 33  63e542d13f747a7a197b9bba         1       2
# 34  63e542c33f747a7a197b9bac         1       2
# 35  63e542973f747a7a197b9b82         1       2
# 36  63e5428a3f747a7a197b9b74         1       2
# 37  64c97d56d590f3086430cabe         1       2
# 38  6717fbfd9d87c463f63b7510         0       2
# 39  63e543233f747a7a197b9c17         3       2
#
#                                             onetTitle
# 0                         Human Resources Specialists
# 1     Software Quality Assurance Analysts and Testers
# 2                                 Software Developers
# 3         Network and Computer Systems Administrators
# 4                                   Graphic Designers
# 5                                       Loan Officers
# 6   Sales Representatives, Wholesale and Manufactu...
# 7   Property, Real Estate, and Community Associati...
# 8                              Insurance Sales Agents
# 9      Claims Adjusters, Examiners, and Investigators
# 10  Industrial Engineering Technologists and Techn...
# 11  Electrical and Electronic Engineering Technolo...
# 12                                     Web Developers
# 13  Bus and Truck Mechanics and Diesel Engine Spec...
# 14                           Real Estate Sales Agents
# 15               Police and Sheriff's Patrol Officers
# 16            Plumbers, Pipefitters, and Steamfitters
# 17                                       Electricians
# 18   Mobile Heavy Equipment Mechanics, Except Engines
# 19                               Pharmacy Technicians
# 20                                  Dental Assistants
# 21                                         Paramedics
# 22       Automotive Service Technicians and Mechanics
# 23  Telecommunications Equipment Installers and Re...
# 24  Heating, Air Conditioning, and Refrigeration M...
# 25                                      Phlebotomists
# 26                        Medical Records Specialists
# 27                                 Medical Assistants
# 28  Licensed Practical and Licensed Vocational Nurses
# 29                             Surgical Technologists
# 30                  Computer User Support Specialists
# 31       Bookkeeping, Accounting, and Auditing Clerks
# 32        Production, Planning, and Expediting Clerks
# 33           Welders, Cutters, Solderers, and Brazers
# 34                      Solar Photovoltaic Installers
# 35     Electrical Power-Line Installers and Repairers
# 36                                         Carpenters
# 37  Operating Engineers and Other Construction Equ...
# 38             Industrial Truck and Tractor Operators
# 39            Heavy and Tractor-Trailer Truck Drivers

# %%
careers.to_csv('cleaned_careers.csv', index=False)

from google.colab import files
# files.download('cleaned_resources.csv')

# %%
dataset_id = "wpac_data"

client = bigquery.Client(project=project_id)
datasets = [dataset.dataset_id for dataset in client.list_datasets()]
print("Available Datasets:", datasets)

if dataset_id not in datasets:
    print(f"Dataset {dataset_id} does not exist. Creating it now...")
    dataset_ref = client.dataset(dataset_id)
    dataset = bigquery.Dataset(dataset_ref)
    dataset.location = "US"  # Change if necessary
    client.create_dataset(dataset, exists_ok=True)
    print(f"Dataset {dataset_id} created.")
# Out:
# Available Datasets: ['wpac_data']

# %%
import pandas_gbq

dataset_table = "wpac_data.cleaned_careers"  # Replace with dataset.table name

# Load your CSV into a DataFrame
csv_file_path = "cleaned_careers.csv"  # Replace with your actual file path
# df = pd.read_csv(csv_file_path)

# Use `pandas_gbq.to_gbq` to upload DataFrame
pandas_gbq.to_gbq(
    careers,
    destination_table=dataset_table,
    project_id=project_id,
    if_exists="replace"  # "fail", "replace", "append"
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 6132.02it/s]
